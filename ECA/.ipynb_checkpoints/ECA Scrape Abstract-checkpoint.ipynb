# %%
import requests
import json
import bs4
import time
import numpy as np
import pandas as pd

import sys
import signal

from itertools import islice   


import CONFIG

# %%
def getBSFromURL(url):
    try:
        r = requests.get(url, headers = CONFIG.HEADER)
        return getBS(r.text)
    
    except requests.exceptions.RequestException as e:
        print("Connection Error")

def getBS(html):
    html_bs = bs4.BeautifulSoup(html, 'html.parser')
    return html_bs

# %%
# a very simple sleeping function to avoid getting banned
def ImNotRobot(t = 5):
    sleepTime = np.random.uniform(t,t+5)
    print(f"sleeping {sleepTime} seconds")
    time.sleep(sleepTime)
    


def getAbstract(url):
    metadata_id = url.split('/')[-1]
    
    r = requests.get('https://www.jstor.org/stable/content-metadata/'+metadata_id, headers = CONFIG.HEADER)
    
    ## check if blocked
    if not r: 
        import Blocked
        raise Blocked.BlockedError("You might be blocked")
    
    article_data = json.loads(r.text)

    abstract = article_data['abstract']
    if len(abstract) == 0 : return ''
    
    return abstract[0]

def save():
    articles_df.to_csv(file_name, index = False)
    
def saveAndQuit(sig=None, frame=None):
    save()
    sys.exit(0)

# %%
file_name = f'{CONFIG.JOURNAL_NAME}.csv'

articles_df = pd.read_csv(file_name)
not_yet_scraped_articles_df = articles_df[(articles_df['scraped'] == 0)]
display(not_yet_scraped_articles_df)

signal.signal(signal.SIGINT, saveAndQuit)

counter = 1
num = len(not_yet_scraped_articles_df)
for index, articles in not_yet_scraped_articles_df.iterrows():
    ImNotRobot()
    try:
        print(f"Scraping {counter} / {num} ...")
        url = articles['Source URL']
        abstract = getAbstract(url)
        print (abstract)
        articles_df.loc[index, 'Abstract'] = abstract
        articles_df.loc[index, 'scraped'] = 1
        
        save()
        if counter % 50 == 0 :
            ImNotRobot(60)
        counter += 1
    except Exception as e:
        print (e)
        saveAndQuit()
# Out:
#                                 Source URL  \
# 2091  https://www.jstor.org/stable/1913151
# 2092  https://www.jstor.org/stable/1913152
# 2093  https://www.jstor.org/stable/1913153
# 2094  https://www.jstor.org/stable/1913154
# 2095  https://www.jstor.org/stable/1913155
# ...                                    ...
# 4598  https://www.jstor.org/stable/1907212
# 4599  https://www.jstor.org/stable/1907213
# 4600  https://www.jstor.org/stable/1907214
# 4601  https://www.jstor.org/stable/1907215
# 4602  https://www.jstor.org/stable/1907219
#
#                                                   Title  \
# 2091  The Durable Goods Monopolist and Consistency w...
# 2092  An Information Good Market with Symmetric Exte...
# 2093  An Example of Price Formation in Bilateral Sit...
# 2094                Multistage Games with Communication
# 2095  A Utility Representation for a Preference Rela...
# ...                                                 ...
# 4598  The Theory of Demand Applied to the French Gas...
# 4599            A Note on the Pure Theory of Production
# 4600  Homogeneous Systems in Mathematical Economics:...
# 4601          A Note on Tintner's "Homogeneous Systems"
# 4602                                 Treasurer's Report
#
#                      Long Volume Issue Vol. Issue No. Month  Year Abstract  \
# 2091  Vol. 54, No. 2, Mar., 1986    Vol. 54     No. 2  Mar.  1986      NaN
# 2092  Vol. 54, No. 2, Mar., 1986    Vol. 54     No. 2  Mar.  1986      NaN
# 2093  Vol. 54, No. 2, Mar., 1986    Vol. 54     No. 2  Mar.  1986      NaN
# 2094  Vol. 54, No. 2, Mar., 1986    Vol. 54     No. 2  Mar.  1986      NaN
# 2095  Vol. 54, No. 2, Mar., 1986    Vol. 54     No. 2  Mar.  1986      NaN
# ...                          ...        ...       ...   ...   ...      ...
# 4598  Vol. 18, No. 1, Jan., 1950    Vol. 18     No. 1  Jan.  1950      NaN
# 4599  Vol. 18, No. 1, Jan., 1950    Vol. 18     No. 1  Jan.  1950      NaN
# 4600  Vol. 18, No. 1, Jan., 1950    Vol. 18     No. 1  Jan.  1950      NaN
# 4601  Vol. 18, No. 1, Jan., 1950    Vol. 18     No. 1  Jan.  1950      NaN
# 4602  Vol. 18, No. 1, Jan., 1950    Vol. 18     No. 1  Jan.  1950      NaN
#
#                  Author 1 Author 2  ... Author 22 Author 23 Author 24  \
# 2091         Charles Kahn      NaN  ...       NaN       NaN       NaN
# 2092          Shigeo Muto      NaN  ...       NaN       NaN       NaN
# 2093          Motty Perry      NaN  ...       NaN       NaN       NaN
# 2094     Roger B. Myerson      NaN  ...       NaN       NaN       NaN
# 2095      Marcus Berliant      NaN  ...       NaN       NaN       NaN
# ...                   ...      ...  ...       ...       ...       ...
# 4598  Michael J. Verhulst      NaN  ...       NaN       NaN       NaN
# 4599          Kenneth May      NaN  ...       NaN       NaN       NaN
# 4600     Kenneth J. Arrow      NaN  ...       NaN       NaN       NaN
# 4601      Cecil G. Phipps      NaN  ...       NaN       NaN       NaN
# 4602        Alfred Cowles      NaN  ...       NaN       NaN       NaN
#
#      Author 25  Author 26  Author 27  Author 28  Author 29  Author 30  scraped
# 2091       NaN        NaN        NaN        NaN        NaN        NaN        0
# 2092       NaN        NaN        NaN        NaN        NaN        NaN        0
# 2093       NaN        NaN        NaN        NaN        NaN        NaN        0
# 2094       NaN        NaN        NaN        NaN        NaN        NaN        0
# 2095       NaN        NaN        NaN        NaN        NaN        NaN        0
# ...        ...        ...        ...        ...        ...        ...      ...
# 4598       NaN        NaN        NaN        NaN        NaN        NaN        0
# 4599       NaN        NaN        NaN        NaN        NaN        NaN        0
# 4600       NaN        NaN        NaN        NaN        NaN        NaN        0
# 4601       NaN        NaN        NaN        NaN        NaN        NaN        0
# 4602       NaN        NaN        NaN        NaN        NaN        NaN        0
#
# [2512 rows x 39 columns]
# sleeping 7.528467278873235 seconds
# Scraping 1 / 2512 ...
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# You might be blocked
# Traceback (most recent call last):
#   File "<ipython-input-8-cd6195e49bc9>", line 16, in <module>
#     abstract = getAbstract(url)
#   File "<ipython-input-5-07140b269a63>", line 17, in getAbstract
#     raise Blocked.BlockedError("You might be blocked")
# Blocked.BlockedError: You might be blocked
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-cd6195e49bc9>", line 27, in <module>
#     saveAndQuit()
#   File "<ipython-input-5-07140b269a63>", line 31, in saveAndQuit
#     sys.exit(0)
# SystemExit: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# BlockedError                              Traceback (most recent call last)
# <ipython-input-8-cd6195e49bc9> in <module>
#      15         url = articles['Source URL']
# ---> 16         abstract = getAbstract(url)
#      17         print (abstract)
#
# <ipython-input-5-07140b269a63> in getAbstract(url)
#      16         import Blocked
# ---> 17         raise Blocked.BlockedError("You might be blocked")
#      18
#
# BlockedError: You might be blocked
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-8-cd6195e49bc9> in <module>
#      26         print (e)
# ---> 27         saveAndQuit()
#      28
#
# <ipython-input-5-07140b269a63> in saveAndQuit(sig, frame)
#      30     save()
# ---> 31     sys.exit(0)
#
# SystemExit: 0
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2035                     stb = ['An exception has occurred, use %tb to see '
#    2036                            'the full traceback.\n']
# -> 2037                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2038                                                                      value))
#    2039                 else:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     821         value : exception value
#     822         """
# --> 823         return ListTB.structured_traceback(self, etype, value)
#     824
#     825     def show_exception_only(self, etype, evalue):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     696             chained_exceptions_tb_offset = 0
#     697             out_list = (
# --> 698                 self.structured_traceback(
#     699                     etype, evalue, (etb, chained_exc_ids),
#     700                     chained_exceptions_tb_offset, context)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1433         else:
#    1434             self.tb = tb
# -> 1435         return FormattedTB.structured_traceback(
#    1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1333         if mode in self.verbose_modes:
#    1334             # Verbose modes need a full traceback
# -> 1335             return VerboseTB.structured_traceback(
#    1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1190         """Return a nice text document describing the traceback."""
#    1191
# -> 1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1193                                                                tb_offset)
#    1194
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
r = requests.get('https://www.jstor.org/stable/content-metadata/1813673', headers = CONFIG.HEADER).text

# %%
rj=json.loads(r)

# %%
rj['abstract']
# Out:
# []

# %%
getAbstract('https://www.jstor.org/stable/116861')
# Out:
# ---------------------------------------------------------------------------
# BlockedError                              Traceback (most recent call last)
# <ipython-input-16-36811012aaa6> in <module>
# ----> 1 getAbstract('https://www.jstor.org/stable/116861')
#
# <ipython-input-5-07140b269a63> in getAbstract(url)
#      15     if not r:
#      16         import Blocked
# ---> 17         raise Blocked.BlockedError("You might be blocked")
#      18
#      19     article_data = json.loads(r.text)
#
# BlockedError: You might be blocked

# %%
articles_df = pd.read_csv(file_name)

# %%
articles_df
# Out:
#                                 Source URL  \
# 0      https://www.jstor.org/stable/116860
# 1      https://www.jstor.org/stable/116861
# 2      https://www.jstor.org/stable/116862
# 3      https://www.jstor.org/stable/116863
# 4      https://www.jstor.org/stable/116864
# ...                                    ...
# 3581  https://www.jstor.org/stable/1813671
# 3582  https://www.jstor.org/stable/1813672
# 3583  https://www.jstor.org/stable/1813673
# 3584  https://www.jstor.org/stable/1813674
# 3585  https://www.jstor.org/stable/1813675
#
#                                                   Title  \
# 0     The Value of Weather Information Services for ...
# 1     The Rise and Fall of Bank Control in the Unite...
# 2     Winners and Losers in Russia's Economic Transi...
# 3     Unemployment and the Social Safety Net during ...
# 4             Federalism and the Soft Budget Constraint
# ...                                                 ...
# 3581     Minimizing AEA Convention Transportation Costs
# 3582  Hedging and the Competitive Firm Under Price U...
# 3583  Unanticipated Money Growth and Unemployment in...
# 3584  Unanticipated Money Growth and Unemployment in...
# 3585  Professorial Behavior Given a Stochastic Rewar...
#
#                      Long Volume Issue Vol. Issue No. Month  Year  \
# 0     Vol. 88, No. 5, Dec., 1998    Vol. 88     No. 5  Dec.  1998
# 1     Vol. 88, No. 5, Dec., 1998    Vol. 88     No. 5  Dec.  1998
# 2     Vol. 88, No. 5, Dec., 1998    Vol. 88     No. 5  Dec.  1998
# 3     Vol. 88, No. 5, Dec., 1998    Vol. 88     No. 5  Dec.  1998
# 4     Vol. 88, No. 5, Dec., 1998    Vol. 88     No. 5  Dec.  1998
# ...                          ...        ...       ...   ...   ...
# 3581  Vol. 69, No. 5, Dec., 1979    Vol. 69     No. 5  Dec.  1979
# 3582  Vol. 69, No. 5, Dec., 1979    Vol. 69     No. 5  Dec.  1979
# 3583  Vol. 69, No. 5, Dec., 1979    Vol. 69     No. 5  Dec.  1979
# 3584  Vol. 69, No. 5, Dec., 1979    Vol. 69     No. 5  Dec.  1979
# 3585  Vol. 69, No. 5, Dec., 1979    Vol. 69     No. 5  Dec.  1979
#
#                                                Abstract  \
# 0     The U.S. government established a national wea...
# 1     This article studies how equity ownership and ...
# 2     The transition to a market economy has produce...
# 3     We investigate the remarkably short unemployme...
# 4     The government's incentives to bail out ineffi...
# ...                                                 ...
# 3581                                                NaN
# 3582                                                NaN
# 3583                                                NaN
# 3584                                                NaN
# 3585                                                NaN
#
#                    Author 1      Author 2           Author 3 Author 4  \
# 0             Erik D. Craft           NaN                NaN      NaN
# 1     Miguel Cantillo Simon           NaN                NaN      NaN
# 2        Elizabeth Brainerd           NaN                NaN      NaN
# 3               John C. Ham   Jan Svejnar  Katherine Terrell      NaN
# 4               Yingyi Qian    Gérard Rol                NaN      NaN
# ...                     ...           ...                ...      ...
# 3581      John J. Siegfried  Larry Nelson                NaN      NaN
# 3582   Duncan M. Holthausen           NaN                NaN      NaN
# 3583         David H. Small           NaN                NaN      NaN
# 3584        Robert J. Barro           NaN                NaN      NaN
# 3585      William E. Becker           Jr.                NaN      NaN
#
#      Author 5 Author 6 Author 7 Author 8  scraped
# 0         NaN      NaN      NaN      NaN        1
# 1         NaN      NaN      NaN      NaN        1
# 2         NaN      NaN      NaN      NaN        1
# 3         NaN      NaN      NaN      NaN        1
# 4         NaN      NaN      NaN      NaN        1
# ...       ...      ...      ...      ...      ...
# 3581      NaN      NaN      NaN      NaN        0
# 3582      NaN      NaN      NaN      NaN        0
# 3583      NaN      NaN      NaN      NaN        0
# 3584      NaN      NaN      NaN      NaN        0
# 3585      NaN      NaN      NaN      NaN        0
#
# [3586 rows x 17 columns]

# %%
r
# Out:
# '<!DOCTYPE html>\n<html class="popup no-js" lang="en">\n  <head>\n    <meta name="robots" content="noarchive,NOODP" />\n    <meta name="description" content="JSTOR is a digital library of academic journals, books, and primary sources." />\n    <meta name="viewport" content="width=device-width" />\n    <meta charset="UTF-8"/>\n    <link rel="stylesheet" href="/assets/global_20171026T1134/build/global/css/popup.css" />\n    <link rel="apple-touch-icon" href="/assets/global_20171026T1134/build/images/apple-touch-icon.png" />\n    <title>JSTOR: Access Check</title>\n    <!-- Custom CSS --> \n  </head>\n  <body>\n    <div class="logo-container">\n      <a href="/"><img src="/assets/global_20171026T1134/build/images/jstor-logo.png" srcset="/assets/global_20171026T1134/build/images/jstor-logo.png" class="non-responsive" alt="JSTOR Home" width="65" height="90" /></a>\n    </div>\n    <div id="content" role="main" class="row content brdra">\n      <div class="small-12 columns paxl mtxl">\n        <div class="row popup-inner">\n          <div class="small-12 columns noGlobalSrch">\n            <h2>Access Check</h2>\n            <p>Our systems have detected unusual traffic activity from your network. Please complete this reCAPTCHA to demonstrate that it\'s\n               you making the requests and not a robot. If you are having trouble seeing or completing this challenge,\n               <a href="https://support.jstor.org/hc/en-us/articles/115011068868-Troubleshooting-CAPTCHA-" target="_blank" title="This link opens in a new window">this page</a> may help.\n               If you continue to experience issues, you can <a href="https://support.jstor.org/" target="_blank" title="This link opens in a new window">contact JSTOR support</a>.</p>\n            <div id="px-captcha"> </div>\n            <p>Block Reference: #d084504d-8371-11ec-82c0-544b55784c73<br/>\n               VID: #<br/>\n               IP: 140.112.71.188<br/>\n               Date and time: Tue, 01 Feb 2022 15:15:39 GMT<br/>\n               <noscript>Javascript is disabled</noscript></p>\n            <p>Go back to <a href="/" title="Go back to JSTOR">JSTOR</a></p>\n          </div>\n        </div>\n      </div>\n    </div>\n    <div class="row">\n      <div class="small-12 columns pts">\n        <small>&copy;2000-<script type="text/javascript">document.write(new Date().getFullYear());</script> ITHAKA. All Rights Reserved. JSTOR&reg;, the JSTOR logo, JPASS&reg;, and ITHAKA&reg; are registered trademarks of ITHAKA.</small>\n      </div>\n    </div>\n    <!-- Px --> <script> window._pxAppId = \'PXu4K0s8nX\'; window._pxJsClientSrc = \'/u4K0s8nX/init.js\'; window._pxFirstPartyEnabled = true; window._pxVid = \'\'; window._pxUuid = \'d084504d-8371-11ec-82c0-544b55784c73\'; window._pxHostUrl = \'/u4K0s8nX/xhr\'; </script>\n    <script> var s = document.createElement(\'script\'); s.src = \'/u4K0s8nX/captcha/captcha.js?a=c&u=d084504d-8371-11ec-82c0-544b55784c73&v=&m=0\'; var p = document.getElementsByTagName(\'head\')[0]; p.insertBefore(s, null); if (true ){s.onerror = function () {s = document.createElement(\'script\'); var suffixIndex = \'/u4K0s8nX/captcha/captcha.js?a=c&u=d084504d-8371-11ec-82c0-544b55784c73&v=&m=0\'.indexOf(\'/captcha.js\'); var temperedBlockScript = \'/u4K0s8nX/captcha/captcha.js?a=c&u=d084504d-8371-11ec-82c0-544b55784c73&v=&m=0\'.substring(suffixIndex); s.src = \'//captcha.px-cdn.net/PXu4K0s8nX\' + temperedBlockScript; p.parentNode.insertBefore(s, p);};}</script>\n    <!-- Custom Script --> \n  </body>\n</html>'
