# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Address': ['4860 Sunset Boulevard,San Francisco and California',
                '3055 Paradise Lane,Salt Lake Cityand Utah',
                '682 Main Street,Detroit and Michigan',
                '9001 Cascade Road,Kansas City and Missouri'],
    'o':[9,8,7,6]
})
# display the dataframe
df
# Out:
#                                              Address  o
# 0  4860 Sunset Boulevard,San Francisco and Califo...  9
# 1          3055 Paradise Lane,Salt Lake Cityand Utah  8
# 2               682 Main Street,Detroit and Michigan  7
# 3         9001 Cascade Road,Kansas City and Missouri  6

# %%
df['Address'].str.split('and', expand=True)
# Out:
#                                       0            1
# 0  4860 Sunset Boulevard,San Francisco    California
# 1     3055 Paradise Lane,Salt Lake City         Utah
# 2              682 Main Street,Detroit      Michigan
# 3        9001 Cascade Road,Kansas City      Missouri

# %%
'(?i)' + '|'.join(exclude_words)
# Out:
# '(?i)Report of|Report on|Annual Report'

# %%
arts = pd.read_csv('ECA_orig.csv')
arts
# Out:
#      https://www.jstor.org/stable/45238023  \
# 0    https://www.jstor.org/stable/45238024
# 1    https://www.jstor.org/stable/45238025
# 2    https://www.jstor.org/stable/45238026
# 3    https://www.jstor.org/stable/45238027
# 4    https://www.jstor.org/stable/45238028
# ..                                     ...
# 123  https://www.jstor.org/stable/44955200
# 124  https://www.jstor.org/stable/44955201
# 125  https://www.jstor.org/stable/44955202
# 126  https://www.jstor.org/stable/44955204
# 127  https://www.jstor.org/stable/44955205
#
#     THE AGGREGATE IMPLICATIONS OF REGIONAL BUSINESS CYCLES  \
# 0    BARGAINING UNDER STRATEGIC UNCERTAINTY: THE RO...
# 1    STRATEGIC COMMUNICATION WITH MINIMAL VERIFICATION
# 2         DYNAMIC QUANTILE MODELS OF RATIONAL BEHAVIOR
# 3                               DYNAMIC RANDOM UTILITY
# 4                      STRATEGICALLY SIMPLE MECHANISMS
# ..                                                 ...
# ...

# %%
display(arts[arts['scraped']==1]
       )
# Out:
#                                  Source URL  \
# 0     https://www.jstor.org/stable/45238023
# 1     https://www.jstor.org/stable/45238024
# 2     https://www.jstor.org/stable/45238025
# 3     https://www.jstor.org/stable/45238026
# 4     https://www.jstor.org/stable/45238027
# ...                                     ...
# 4285   https://www.jstor.org/stable/1909472
# 4286   https://www.jstor.org/stable/1909473
# 4287   https://www.jstor.org/stable/1909474
# 4288   https://www.jstor.org/stable/1909475
# 4289   https://www.jstor.org/stable/1909440
#
#                                                   Title  \
# 0     THE AGGREGATE IMPLICATIONS OF REGIONAL BUSINES...
# 1     BARGAINING UNDER STRATEGIC UNCERTAINTY: THE RO...
# 2     STRATEGIC COMMUNICATION WITH MINIMAL VERIFICATION
# 3          DYNAMIC QUANTILE MODELS OF RATIONAL BEHAVIOR
# 4                                DYNAMIC RANDOM UTILITY
# ...                                                 ...
# ...

# %%
def has2019(r):
    return r

df_all_issue = pd.read_csv('ECA_all_issue.csv')
display(df_all_issue[df_all_issue['name'].str.contains('May')])
# Out:
#                 name                        url  scraped
# 3     No. 3 May 2019  /stable/10.2307/i40222383        1
# 9     No. 3 May 2018  /stable/10.2307/i40210231        1
# 15    No. 3 May 2017  /stable/10.2307/i40210225        1
# 21    No. 3 May 2016  /stable/10.2307/i40158908        1
# 27    No. 3 May 2015  /stable/10.2307/i40144632        1
# 33    No. 3 May 2014  /stable/10.2307/i24021374        1
# 39    No. 3 May 2013  /stable/10.2307/i23517479        1
# 45    No. 3 May 2012  /stable/10.2307/i40072982        1
# 51   No. 3 May, 2011  /stable/10.2307/i40055873        1
# 57   No. 3 May, 2010  /stable/10.2307/i40028912        1
# 63   No. 3 May, 2009  /stable/10.2307/i40010228        1
# 69   No. 3 May, 2008  /stable/10.2307/i40002372        1
# 75   No. 3 May, 2007    /stable/10.2307/i405515        1
# 81   No. 3 May, 2006    /stable/10.2307/i383434        1
# 87   No. 3 May, 2005    /stable/10.2307/i282644        1
# ...

# %%
import requests

# %%
def timeTest():
    return requests.get('https://httpstat.us/200?sleep=5000', timeout = 5)

# %%
try:
    timeTest()
except requests.ReadTimeout as e:
    print(e)
    raise e
# Out:
# HTTPSConnectionPool(host='httpstat.us', port=443): Read timed out. (read timeout=5)
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# ...

# %%
import numpy as np
np.array([0,1,0,0,1]) & np.array([1,1,0,0,1])
# Out:
# array([0, 1, 0, 0, 1])

# %%
('ON THE ASYMPTOTIC SIZES OF SUBSET ANDERSON—RUBIN AND LAGRANGE MULTIPLIER TESTS IN LINEAR INSTRUMENTAL VARIABLES REGRESSION').capitalize()
# Out:
# 'On the asymptotic sizes of subset anderson—rubin and lagrange multiplier tests in linear instrumental variables regression'
