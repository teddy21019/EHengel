# %%
import requests
import json
import re
import bs4
import time
import numpy as np
import pandas as pd

import sys
from os.path import exists
import signal

import CONFIG

# %%
def getBSFromURL(url):
    try:
        r = requests.get(url, headers = CONFIG.HEADER, timeout = 10)
        return getBS(r.text)
    
    except requests.exceptions.RequestException as e:
        print("Connection Error")
        raise e
    except requests.ReadTimeout as e:
        print("Timeout")
        raise e

def getBS(html):
    html_bs = bs4.BeautifulSoup(html, 'html.parser')
    return html_bs

# %% [markdown]
# ## Get all Issues from selected decades
#
# We scrape all the information of articles first from the main page of JSTOR.
#
# By default, as in https://www.jstor.org/journal/amereconrevi, the titles of decades are first listed. Clicking on the decade makes an request to JSTOR backend to get the full list of the issues within the decade.
#
# The request are in the form of `https://www.jstor.org/journal/amereconrevi/decade/` + `ID`, where the `ID` is stored in the `data-filter` attribute in the element with class `expand-arrow`.
#
# This returns a json object which contains the HTML element to append in the `ul` element, but we can simply turn them into `soup` objects and extract the link to the issues as well as the issue name, which are the `href` and the `text` of the `"a"` selector, respectively.

# %%
# a very simple sleeping function to avoid getting banned
def ImNotRobot(t = 5):
    sleepTime = np.random.uniform(t,t+5)
    print(f"sleeping {sleepTime} seconds")
    time.sleep(sleepTime)

# see if list of issue file already exist
def file(path_to_file):

    return exists(path_to_file)


# get url that returns all list if issues within the decade
def getURLinDecade(journal_url, decade_list):
    
    journal_bs = getBSFromURL(journal_url)
    all_decade_informations = journal_bs.select(".expand-arrow")
    
    needed_decade_informations = list(filter( 
        lambda x: (int(x['data-decade']) in decade_list), all_decade_informations))
    

    decade_issues_lists_url = [f"{journal_url}/decade/{u['data-filter']}" for u in needed_decade_informations]
    return decade_issues_lists_url

# go over the urls and get the url for all issues

def handleIssueText(t):
    return t.split('pp.')[0].strip()
    

    
def getAllIssuesInDecade(url):
    print ("processing " + url)
    issue_request = requests.get(url, headers = CONFIG.HEADER)

    issue_html = json.loads(issue_request.text)[0]
    soup = getBS(issue_html)
    all_issue = soup.select("a")
    
    print(all_issue)
    issues = []
    for issue in all_issue:
        issue_info = {
            'name':handleIssueText(issue.text),
            'url':issue['href']
        }
        issues.append(issue_info)
        
    return issues

# %%
all_journal_file_name = CONFIG.JOURNAL_NAME + '_all_issue.csv'

counter = 1
if exists(all_journal_file_name):
    pass
else:
    try:
        journal_url = CONFIG.URL
        URLinDecade = getURLinDecade(journal_url, CONFIG.SCRAPE_DECADES)

        allIssues = []
        for u in URLinDecade:
            ImNotRobot()
            allIssues += getAllIssuesInDecade(u)

        all_issues_df = pd.json_normalize(allIssues)
        all_issues_df['scraped'] = 0
        with open(all_journal_file_name, 'w') as fout:
            all_issues_df.to_csv(fout, header=True, index=False)
        
        if counter % 50 == 0 :
            ImNotRobot(120)
            
    except Exception as e:
        raise e

# %% [markdown]
# ## Handling allIsue
#
# We want to create a csv file, or xlsx file, that has the following column names

# %%
colNames = [
    "Source URL",
    "Title",
    "Long Volume",
    "Issue Vol.",
    "Issue No.",
    "Month",
    "Year",
    "Abstract"
]
# + Author List

# %% [markdown]
# I stored the resuls of issues into another file

# %%
def getArticles(url):
    issueBS = getBSFromURL(url)
    
    issue_name = issueBS.select('div.issue')
    if not issue_name:
        import Blocked
        raise Blocked.BlockedError("You might be blocked")
    
    issue_name = issue_name[0].text.strip()
    articlesWithAuthor = issueBS.select('div.contrib')
    return issue_name, articlesWithAuthor

def parseIssue(t):
    separated = t.split(',')
    
    # There are two different formats, yeez@@
    
    ## Vol. 77, No. 4, Jul., 2009
    if len(separated) == 4:
        vol = separated[0].strip()
        no = separated[1].strip()
        month = separated[2].strip()
        year = separated[3].strip()
    
    ##  Vol. 87, No. 4, July 2019
    else:
        vol = separated[0].strip()
        no = separated[1].strip()
        date = separated[2].strip().split(' ')
        month = date[0].strip()
        year = date[1].strip()
    return t, vol, no, month, year

def parseAuthor(a):
    authors = re.split(r'\s+and\s+|,(?!\s*Jr\.)\s*', a)
    split_authors = [e.strip() for e in authors]
    
    split_authors += [None]*(30-len(split_authors))
    return [a]+ split_authors

# %%
with open(all_journal_file_name) as f:
    all_issues_df = pd.read_csv(f)
needed_issues = all_issues_df[all_issues_df['scraped'] ==0 ]
display(needed_issues)

all_articles_file_name = CONFIG.JOURNAL_NAME + "_orig.csv"


counter = 1
for index, issue in needed_issues.iterrows():
    url = CONFIG.DOMAIN_URL + issue['url']
    try:     
        issue_name, articlesWithAuthor = getArticles(url)
        print(f"Processing : {counter}/{len(needed_issues)} \t {issue_name} ...")

        full_vol, vol, no, month, year = parseIssue(issue_name)

        tempArticles = []
        for article in articlesWithAuthor: 
            article_element = article.parent
            article_title = article_element.find('a').text.strip()
            article_url = CONFIG.DOMAIN_URL + article_element.find('a')['href']
            article_authors = parseAuthor( article.text.strip() )

            tempArticles.append([
                article_url,
                article_title,
                full_vol, vol, no, month, year,
                ''
            ] + 
            article_authors)
            print("Article Name  :  " + article_title)
        
        
        all_issues_df.loc[index, 'scraped'] = 1
        
        ## save
        with open(all_journal_file_name, 'w') as issue_f:
            all_issues_df.to_csv(issue_f, 
                                 header=True, 
                                 index=False)
        
        with open(all_articles_file_name, 'a') as article_f:
            tempDF = pd.DataFrame(tempArticles)
            tempDF.to_csv(article_f, 
                                header=False, 
                                index=False)
        print("="*30)
        if counter % 50 == 0 :
            ImNotRobot(120)
        counter += 1
        ImNotRobot()
        
    except Exception as e:
        print(e)
        sys.exit(0)
# Out:
#                           name                      url  scraped
# 309  No. 3/4 Jul. - Oct., 1967  /stable/10.2307/i332542        0
# 310           No. 2 Apr., 1967  /stable/10.2307/i332630        0
# 311           No. 1 Jan., 1967  /stable/10.2307/i332629        0
# 312           No. 4 Oct., 1966  /stable/10.2307/i332656        0
# 313           No. 3 Jul., 1966  /stable/10.2307/i332655        0
# ..                         ...                      ...      ...
# 373           No. 1 Jan., 1951  /stable/10.2307/i332597        0
# 374           No. 4 Oct., 1950  /stable/10.2307/i332596        0
# 375           No. 3 Jul., 1950  /stable/10.2307/i332530        0
# 376           No. 2 Apr., 1950  /stable/10.2307/i332592        0
# 377           No. 1 Jan., 1950  /stable/10.2307/i332591        0
#
# [69 rows x 3 columns]
# Processing : 1/69 	 Vol. 35, No. 3/4, Jul. - Oct., 1967 ...
# Article Name  :  An Experimental Study of Cooperative Duopoly
# Article Name  :  A Model of the United Kingdom's Monetary Sector
# Article Name  :  Estimation of Returns to Scale and the Elasticity of Substitution
# Article Name  :  Utility Maximization and the Demand for New Zealand Meats
# Article Name  :  Error Produced by Linearization in Mathematical Programming
# Article Name  :  A Test for the Product Life Cycle
# Article Name  :  Additive von Neumann-Morgenstern Utility Functions
# Article Name  :  Elimination of Management Bias from Production Functions Fitted to Cross-Section Data: A Model and an Application to African Agriculture
# Article Name  :  A Comparative Study of Alternative Estimators in a Distributed Lag Model
# Article Name  :  A Continuous Leontief Production Model with Quadratic Objective Function
# Article Name  :  A Note on Orderings
# Article Name  :  Reply to "A Note on Orderings"
# Article Name  :  Computation of Expansion Rates for the Generalized von Neumann Model of an Expanding Economy
# Article Name  :  A First Course in Stochastic Processes
#      by Samuel Karlin
# Article Name  :  A History of Marginal Utility Theory
#      by Emil Kauder
# Article Name  :  Essays on Econometrics and Planning
#      by C. R. Rao, D. B. Lahiri, K. R. Nair, P. Pant, S. G. Shrikhande
# Article Name  :  Finite Mathematics with Applications in the Social and Management Sciences
#      by Louis O. Kattsoff, Albert J. Simone
# Article Name  :  Growth and Structure in the Economy of Modern Italy
#      by George H. Hildebrand
# Article Name  :  Queues and Inventories. A Study of Their Basic Stochastic Processes
#      by N. U. Prabhu
# Article Name  :  Modelli Econometrici Per La Programmazione
# Article Name  :  Contributions to Statistics
#      by C. R. Rao, D. B. Lahiri, K. R. Nair, P. Pant, S. G. Shrikhande
# Article Name  :  Über optimales wirtschaftliches Wachstum. Ein Beitrag zur makroökonomischen Theorie des Investitionsoptimums
#      by H. J. Vosgerau
# Article Name  :  The Use of Mathematics in Economics
#      by V. S. Nemchinov, A. Nove
# Article Name  :  Capital Formation in the United Kingdom, 1920-1938
#      by C. H. Feinstein
# Article Name  :  An Introduction to Probability Theory and Its Applications
#      by William Feller
# Article Name  :  Structure of Transportation Networks. Relationships between Network Geometry and Regional Characteristics
#      by K. J. Kansky
# Article Name  :  Die Anwendung der Linearen Programmierung in Industriebetrieben
#      by Peter Vokuhl
# ==============================
# sleeping 9.404685340157267 seconds
# Processing : 2/69 	 Vol. 35, No. 2, Apr., 1967 ...
# Article Name  :  Investment Behavior in U.S. Manufacturing, 1947-1960
# Article Name  :  Qualitative Economics and Morishima Matrices
# Article Name  :  An Infinite-Horizon Discrete-Time Quadratic Program as Applied to a Monopoly Problem
# Article Name  :  Control Systems with Jumps in the State Variables
# Article Name  :  Long-Run Coefficients and Distributed Lag Analysis: A Reformulation
# Article Name  :  Effective Control Through Coherent Decentralization with Preemptive Goals
# Article Name  :  Short-Run Adjustments of an Individual Bank
# Article Name  :  A Model of Business Firm Growth
# Article Name  :  On a Class of Growth Models
# Article Name  :  Specification Analysis in the Estimation of Parameters of a Simultaneous Equation Model with Autoregressive Residuals
# Article Name  :  Decision and Horizon Rules for Stochastic Planning Problems: A Linear Example
# Article Name  :  On Efficient Accumulation Paths in the Closed Production Model
# Article Name  :  Statistical vs. Structural Explanations of Understatement and Regressivity in "Rational" Expectations
# Article Name  :  A Parametric Simplicial Formulation of Houthakker's Capacity Method
# Article Name  :  Application of the General Linear Model to Seasonal Adjustment of Economic Time Series
# Article Name  :  Turnpike Theorem in a Generalized Dynamic Input-Output System
# Article Name  :  Simultaneous Determination of Interest and Prices in Switzerland by a Two-Market Model for Money and Bonds
# Article Name  :  Errors of Measurement and Least Squares Estimation in a Simple Recursive Model of Dynamic Equilibrium
# Article Name  :  The Short-Run Flows of Nonfarm Residential Mortgage Credit
# Article Name  :  A Simplex-Type Algorithm for Linear and Quadratic Programming--A Parametric Procedure
# Article Name  :  Simultaneous Tests for Trend and Serial Correlations for Gaussian Markov Residuals
# Article Name  :  Une Methode Graphique de Resolution de Certains Types de Programmes Lineaires de Grandes Dimensions
# Article Name  :  A Possibility Theorem on Majority Decisions
# Article Name  :  Additivity in Utility Theory with Denumerable Product Sets
# Article Name  :  Consumer Aspects of Price Instability
# Article Name  :  Wholes and Parts: A General Theory of System Behavior
#      by Oskar Lange, Eugenius Lepa
# Article Name  :  Mathematical Theory of Reliability
#      by Richard E. Barlow, Frank Proschan
# Article Name  :  Manufacturing Production Functions in the United States, 1957
#      by George H. Hildebrand, Ta-Chung Liu
# Article Name  :  La Programmation Dynamique
#      by A. Kaufmann, R. Cruon
# Article Name  :  Investment Decisions, Economic Forecasting, and Public Policy
#      by John R. Meyer, Robert R. Glauber
# Article Name  :  Balance of Payments Equilibrium: A Theoretical and Empirical Study
#      by H. G. Georgiadis
# Article Name  :  Linear Programming--An Introductory Analysis
#      by N. Paul Loomba
# Article Name  :  Schätzprobleme in der Ökonometrie: Identifikation und punktuelle Parameter und Prognoseschätzung bei interdependenten Systemen
#      by Dietrich Leudeke
# Article Name  :  Macroeconomics and Programming
#      by Kenneth K. Kurihara
# Article Name  :  Actes de la 3ième conférence internationale de recherche operationelle, Oslo, 1963
#      by G. Kreweras, G. Morlat
# Article Name  :  An Econometric Model of the Greek Economy
#      by Daniel B. Suits
# Article Name  :  Conferencias de Econometria y Metodos Estadisticos
#      by Angel Alcaide Inchausti
# Article Name  :  Die Grundsätze der pluralistischen Wirtschaft
#      by Josef Solterer
# Article Name  :  Accounting and Analytical Methods
#      by Richard Mattessich
# Article Name  :  An Exact Method of Consumer Demand Analysis
# Article Name  :  A Note on Separability in Demand Analysis
# ==============================
# sleeping 6.572246679650593 seconds
# Processing : 7/69 	 Vol. 34, No. 1, Jan., 1966 ...
# Article Name  :  Existence of Competitive Equilibria in Markets with a Continuum of Traders
# Article Name  :  A Survey of the Theory of International Trade: Part 3, The Modern Theory
# Article Name  :  The Stability of Truncated Solutions of Stochastic Linear Programming
# Processing : 67/69 	 Vol. 18, No. 3, Jul., 1950 ...
# Article Name  :  The Work of Eugen Slutsky
# Article Name  :  Empirical Determination of a Multidimensional Marginal Cost Function
# Article Name  :  Stock and Flow Analysis in Economics
# Article Name  :  Stock and Flow Analysis: Comment
# Article Name  :  Stock and Flow Analysis: Further Comment
# Article Name  :  Stock and Flow Analysis: Discussion
# Article Name  :  Stock and Flow Analysis: Note on the Discussion
# Article Name  :  Risk Allowances for Price Expectations
# Article Name  :  A Note on Brand-Names and Related Economic Phenomena
# Article Name  :  Rational Behavior, Uncertain Prospects, and Measurable Utility
# ==============================
# sleeping 8.816445654976524 seconds
# Processing : 68/69 	 Vol. 18, No. 2, Apr., 1950 ...
# Article Name  :  Joseph A. Schumpeter (1883-1950)
# Article Name  :  Rational Behavior, Uncertain Prospects, and Measurable Utility
# Article Name  :  Inversion of the Leontief Matrix by Power Series
# Article Name  :  The Bargaining Problem
# Article Name  :  The Analysis of Output Under Discrimination
# ==============================
# sleeping 8.163983869727199 seconds
# Processing : 69/69 	 Vol. 18, No. 1, Jan., 1950 ...
# Article Name  :  The Notion of Involuntary Economic Decisions
# Article Name  :  The Determinacy of Absolute Prices in Classical Economic Theory
# Article Name  :  The Consistency of the Classical Theory of Money and Prices
# Article Name  :  A Note on Patinkin's "Relative Prices"
# Article Name  :  An Application of Least Squares to Family Diet Surveys
# Article Name  :  The Theory of Demand Applied to the French Gas Industry
# Article Name  :  A Note on the Pure Theory of Production
# Article Name  :  Homogeneous Systems in Mathematical Economics: A Comment
# Article Name  :  A Note on Tintner's "Homogeneous Systems"
# Article Name  :  Report of the Council for 1949
# Article Name  :  Treasurer's Report
# Article Name  :  Criticism Invited
# ==============================
# sleeping 5.316536273202191 seconds

# %% [markdown]
# ## Filter Unwanted Articles
#
# Some articles containing words like
# * Report on
# * Report of
# * annual report
# don't have abstracts, and I exclude them
#
# Also, there are 'Book Reviews', for which the author is in the form of 'Reviewed by:'

# %%
arts = pd.read_csv(all_articles_file_name, header = None)
print(len(arts))
exclude_words = ['Report of','Report on', 'Annual Reports','Criticism Invited']
dont_need = (arts[1].str.contains('|'.join(exclude_words),regex=True, case=False) | 
            arts[8].str.contains('Review by:'))
print("Articles to exclude : "+ str(sum(dont_need)))

articles_remain = arts[~dont_need]
articles_remain

## save those don't need into another file
arts[dont_need].to_csv('ECA_skipped.csv',index = False, header = False)
# Out:
# 5713
# Articles to exclude : 1110

# %% [markdown]
# We add the column name and create a new file with it

# %%
total_column_number = len(articles_remain.columns)
print(total_column_number)

col_name_with_author = colNames + ['Full Author'] + [ f"Author {i+1}" for i in range(total_column_number-9)]
# Out:
# 39

# %%
# articles_remain.columns = col_name_with_author
# articles_remain['scraped'] = [0]*len(articles_remain)
# articles_remain.to_csv(f'{CONFIG.JOURNAL_NAME}.csv', index = False)

# %%
articles_remain.columns = col_name_with_author
articles_remain.to_csv(f'{CONFIG.JOURNAL_NAME}_author_fixed.csv', index = False)
