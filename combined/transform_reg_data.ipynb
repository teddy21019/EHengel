# %% [markdown]
# # Get the Data to be Regression-ready
#
# There are three part in this code.
#
# * Configuration
# * Create Gender Information
# * Get the data to be ready for regression

# %%
import pandas as pd
import numpy as np
import json
import re
import itertools

# %%
with_abs = pd.read_csv('all_combined.csv')
with_abs = with_abs[~with_abs['Abstract'].isnull()]

# %%
with_abs
# Out:
#       Journal                              Source URL  \
# 0         AER     https://www.jstor.org/stable/116860
# 1         AER     https://www.jstor.org/stable/116861
# 2         AER     https://www.jstor.org/stable/116862
# 3         AER     https://www.jstor.org/stable/116863
# 4         AER     https://www.jstor.org/stable/116864
# ...       ...                                     ...
# 22301     RES  https://doi.org/10.1093/restud/rdaa033
# 22302     RES  https://doi.org/10.1093/restud/rdaa054
# 22303     RES  https://doi.org/10.1093/restud/rdaa045
# 22304     RES  https://doi.org/10.1093/restud/rdaa052
# 22305     RES  https://doi.org/10.1093/restud/rdaa041
#
#                                                    Title  \
# 0      The Value of Weather Information Services for ...
# 1      The Rise and Fall of Bank Control in the Unite...
# 2      Winners and Losers in Russia's Economic Transi...
# 3      Unemployment and the Social Safety Net during ...
# 4              Federalism and the Soft Budget Constraint
# ...                                                  ...
# 22301  Development Projects and Economic Networks: Le...
# 22302  Haste or Waste? Peer Pressure and Productivity...
# 22303                 Monetary Policy for a Bubbly World
# 22304  Stability, Strategy-Proofness, and Cumulative ...
# 22305       The Revelation Principle in Multistage Games
#
#                       Long Volume Issue Vol. Issue No. Month    Year  \
# 0      Vol. 88, No. 5, Dec., 1998    Vol. 88     No. 5  Dec.  1998.0
# 1      Vol. 88, No. 5, Dec., 1998    Vol. 88     No. 5  Dec.  1998.0
# 2      Vol. 88, No. 5, Dec., 1998    Vol. 88     No. 5  Dec.  1998.0
# 3      Vol. 88, No. 5, Dec., 1998    Vol. 88     No. 5  Dec.  1998.0
# 4      Vol. 88, No. 5, Dec., 1998    Vol. 88     No. 5  Dec.  1998.0
# ...                           ...        ...       ...   ...     ...
# 22301                         NaN  Volume 88   Issue 3   May  2021.0
# 22302                         NaN  Volume 88   Issue 3   May  2021.0
# 22303                         NaN  Volume 88   Issue 3   May  2021.0
# 22304                         NaN  Volume 88   Issue 3   May  2021.0
# 22305                         NaN  Volume 88   Issue 3   May  2021.0
#
#                                                 Abstract  \
# 0      The U.S. government established a national wea...
# 1      This article studies how equity ownership and ...
# 2      The transition to a market economy has produce...
# 3      We investigate the remarkably short unemployme...
# 4      The government's incentives to bail out ineffi...
# ...                                                  ...
# 22301  This article investigates the effects of devel...
# 22302  Motivated by wide cross-sectional variations i...
# 22303  What is the role of monetary policy in a bubbl...
# 22304  We characterize when a stable and strategy-pro...
# 22305  The communication revelation principle (RP) of...
#
#                                           Full Author               Author 1  \
# 0                                       Erik D. Craft          Erik D. Craft
# 1                               Miguel Cantillo Simon  Miguel Cantillo Simon
# 2                                  Elizabeth Brainerd     Elizabeth Brainerd
# 3      John C. Ham, Jan Svejnar and Katherine Terrell            John C. Ham
# 4                       Yingyi Qian and Gérard Roland            Yingyi Qian
# ...                                               ...                    ...
# 22301                                             NaN              Simon Heß
# 22302                                             NaN           David Silver
# 22303                                             NaN       Vladimir Asriyan
# 22304                                             NaN  John William Hatfield
# 22305                                             NaN           Takuo Sugaya
#
#                   Author 2            Author 3       Author 4 Author 5  \
# 0                      NaN                 NaN            NaN      NaN
# 1                      NaN                 NaN            NaN      NaN
# 2                      NaN                 NaN            NaN      NaN
# 3              Jan Svejnar   Katherine Terrell            NaN      NaN
# 4            Gérard Roland                 NaN            NaN      NaN
# ...                    ...                 ...            ...      ...
# 22301       Dany Jaimovich  Matthias Schündeln            NaN      NaN
# 22302                  NaN                 NaN            NaN      NaN
# 22303         Luca Fornaro      Alberto Martin  Jaume Ventura      NaN
# 22304  Scott Duke Kominers  Alexander Westkamp            NaN      NaN
# 22305   Alexander Wolitzky                 NaN            NaN      NaN
#
#       Author 6 Author 7 Author 8
# 0          NaN      NaN      NaN
# 1          NaN      NaN      NaN
# 2          NaN      NaN      NaN
# 3          NaN      NaN      NaN
# 4          NaN      NaN      NaN
# ...        ...      ...      ...
# 22301      NaN      NaN      NaN
# 22302      NaN      NaN      NaN
# 22303      NaN      NaN      NaN
# 22304      NaN      NaN      NaN
# 22305      NaN      NaN      NaN
#
# [13058 rows x 18 columns]

# %%
authors = pd.read_csv('../Authors/author_sex.csv')

# %%
with_abs_2015 = with_abs[(with_abs['Year']<=2015) & (with_abs['Journal'] != 'RES')]

# %%
all_authors = with_abs_2015.loc[:, [f"Author {i+1}" for i in range(7)]].values.flatten()

all_authors = sorted(list(set(all_authors))[1:])
all_authors  ## all authors in the list that need to match the gender
# Out:
# ['A. A. Ryvkin',
#  'A. A. Walters',
#  'A. Abigail Payne',
#  'A. Anastasopoulos',
#  'A. Andrew John',
#  'A. Araujo',
#  'A. B. Atkinson',
#  'A. B. Z. Salem',
#  'A. Belloni',
#  'A. Ben-Israel',
#  'A. Ben-Tal',
#  'A. C. Harvey',
#  'A. Charnes',
#  'A. Colin Cameron',
#  'A. D. Woodland',
#  'A. F. Shorrocks',
#  'A. G. Doig',
#  'A. H. Land',
#  'A. Holly',
#  'A. Joshua Strickland',
#  'A. K. Skiba',
#  'A. Khan',
#  'A. Kirman',
#  'A. L. Nagar',
#  'A. Lans Bovenberg',
#  'A. M. Buoncristiani',
#  'A. M. Kshirsagar',
#  'A. M. Robert Taylor',
#  'A. Mas-Colell',
#  'A. McLennan',
#  'A. Michael Spence',
#  'A. Mitchell Polinsky',
#  'A. Monfort',
#  'A. Mushfiq Mobarak',
#  'A. Nataf',
#  'A. P. Barten',
#  'A. Pakes',
#  'A. R. Bergstrom',
#  'A. R. Ferguson',
#  'A. R. Pagan',
#  'A. Robert Nobay',
#  'A. Rodney Dobell',
#  'A. Ronald Gallant',
#  'A. S. Deaton',
#  'A. S. Goldberger',
#  'A. S. Rao',
#  'A. Simonovits',
#  'A. T. Denzau',
#  'A. Thomas King',
#  'A. Trognon',
#  'A. Zabalza',
#  'A. Zellner',
#  'A. de Palma',
#  'A. ten Kate',
#  'Aanund Hylland',
#  'Aaron Roth',
#  'Aaron S. Edlin',
#  'Aaron S. Yelowitz',
#  'Aaron Tornell',
#  'Aaron Yelowitz',
#  'Aart Kraay',
#  'Aarón Tornell',
#  'Aba Schwartz',
#  'Abba M. Krieger',
#  'Abel Winn',
#  'Abhijit Banerjee',
#  'Abhijit Sengupta',
#  'Abhijit V. Banerjee',
#  'Abraham Charnes',
#  'Abraham L. Wickelgren',
#  'Abraham Neyman',
#  'Abraham Robinson',
#  'Abraham Subotnik',
#  'Abram Bergson',
#  'Adam B. Jaffe',
#  'Adam Brandenburger',
#  'Adam Guren',
#  'Adam Hale Shapiro',
#  'Adam Kalai',
#  'Adam Looney',
#  'Adam M. Rosen',
#  'Adam Ray',
#  'Adam Storeygard',
#  'Adam Szeidl',
#  'Adam Wantz',
#  'Adib Bagh',
#  'Adriaan Soetevent',
#  'Adrian Bruhin',
#  'Adrian Peralta-Alva',
#  'Adriana D. Kugler',
#  'Adriana Lleras-Muney',
#  'Adrien Verdelhan',
#  'Ady Pauzner',
#  'Agar Brugiavini',
#  'Agnar Sandmo',
#  'Agustín Maravall',
#  'Ahmed Mushfiq Mobarak',
#  'Ahmed S. Rahman',
#  'Ahmet Alkan',
#  'Ahsan Mansur',
#  "Ahuva Mu'alem",
#  'Aico van Vuuren',
#  'Ailsa Röell',
#  'Ajay Maindiratta',
#  'Akhmed Akhmedov',
#  'Akira Okada',
#  'Akira Yamazaki',
#  'Akram Temimi',
#  'Akwasi Nti-Addae',
#  'Al H. Ringleb',
#  'Al Slivinski',
#  'Alain C. Enthoven',
#  'Alain Monfort',
#  'Alain Trannoy',
#  'Alan B. Keueger',
#  'Alan B. Krueger',
#  'Alan Beggs',
#  'Alan C. Hess',
#  'Alan C. Stockman',
#  'Alan D. Woodland',
#  'Alan Duncan',
#  'Alan Harrison',
#  'Alan Heston',
#  'Alan I. Barreca',
#  'Alan J. Auerbach',
#  'Alan J. Marcus',
#  'Alan K. Fox',
#  'Alan Kirman',
#  'Alan Krueger',
#  'Alan L. Gustman',
#  'Alan L. Olmstead',
#  'Alan M. Taylor',
#  'Alan Manning',
#  'Alan Mathios',
#  'Alan P. Kirman',
#  'Alan Powell',
#  'Alan R. Rogers',
#  'Alan S. Blinder',
#  'Alan S. Frankel',
#  'Alan S. Manne',
#  'Alan Schwartz',
#  'Alan Slivinski',
#  'Alan Sorensen',
#  'Alan Spiro',
#  'Alan T. Peacock',
#  'Alan T. Sorensen',
#  'Alan V. Deardorff',
#  'Albert Ando',
#  'Albert Breton',
#  'Albert Madansky',
#  'Albert Marcet',
#  'Albert N. Link',
#  'Albert S. Kyle',
#  'Albert Saiz',
#  'Alberto Abadie',
#  'Alberto Alesina',
#  'Alberto Bennardo',
#  'Alberto Bisin',
#  'Alberto Cavallo',
#  'Alberto Dávila',
#  'Alberto F. Ades',
#  'Alberto Galasso',
#  'Alberto Giovannini',
#  'Alberto Holly',
#  'Alberto Martin',
#  'Alberto Trejos',
#  'Aldi Hagenaars',
#  'Aldo Rustichini',
#  'Aleh Tsyvinski',
#  'Alejandro Hernández D.',
#  'Alejandro Jofre',
#  'Alejandro Justiniano',
#  'Alejandro M. Manelli',
#  'Alessandra Casella',
#  'Alessandra Fogli',
#  'Alessandra Voena',
#  'Alessandro Chiesa',
#  'Alessandro Citanna',
#  'Alessandro Gavazza',
#  'Alessandro Lizzeri',
#  'Alessandro Pavan',
#  'Alessandro Riboni',
#  'Alex A. Himonas',
#  'Alex Cukierman',
#  'Alex Gershkov',
#  'Alex R. Horenstein',
#  'Alex Rees-Jones',
#  'Alex Tabarrok',
#  'Alexander David',
#  'Alexander F. Wagner',
#  'Alexander Frankel',
#  'Alexander Galetovic',
#  'Alexander Karaivanov',
#  'Alexander Klein',
#  'Alexander L. Brown',
#  'Alexander L. Wolman',
#  'Alexander Ljungqvist',
#  'Alexander Ludwig',
#  'Alexander Monge-Naranjo',
#  'Alexander S. Kelso, Jr.',
#  'Alexander Strand',
#  'Alexander Torgovitsky',
#  'Alexander Van der Bellen',
#  'Alexander Westkamp',
#  'Alexander Wolitzky',
#  'Alexandra Killewald',
#  'Alexandre Mas',
#  'Alexandre Skiba',
#  'Alexandru Nichifor',
#  'Alexei Onatski',
#  'Alexey Kushnir',
#  'Alexis Akira Toda',
#  'Alexis Jacquemin',
#  'Alfonso Flores-Lagunes',
#  'Alfonso Irarrazabal',
#  'Alfonso Novales',
#  'Alfonso Rosolia',
#  'Alfred Cowles',
#  'Alfred Galichon',
#  'Alfred Lorn Norman',
#  'Ali Hortaçsu',
#  'Ali Shourideh',
#  'Ali Yurukoglu',
#  'Alice Nakamura',
#  'Alicia H. Munnell',
#  'Alireza Tahbaz-Salehi',
#  'Alisdair McKay',
#  'Alison P. Hagy',
#  'Alistair J. Wilson',
#  'Alistair Munro',
#  'Alix Peterson Zwane',
#  'Alla Lileeva',
#  'Allan A. Zebedee',
#  'Allan Collard-Wexler',
#  'Allan Drazen',
#  'Allan G. Timmermann',
#  'Allan Gibbard',
#  'Allan H. Meltzer',
#  'Allan M. Feldman',
#  'Allan Sly',
#  'Allan Timmermann',
#  'Allan W. Kleidon',
#  'Allan Zelenitz',
#  'Allen C. Kelley',
#  'Allen J. Scafuri',
#  'Allen N. Berger',
#  'Allen R. Sanderson',
#  'Almarin Phillips',
#  'Aloisio Araujo',
#  'Alok Bhargava',
#  'Alon Brav',
#  'Aloysius Siow',
#  'Alp E. Atakan',
#  'Alp Simsek',
#  'Alpo Willman',
#  'Alvaro Rodriguez',
#  'Alvaro Sandroni',
#  'Alvin C. Egbert',
#  'Alvin D. Murphy',
#  'Alvin E. Roth',
#  'Alvin K. Klevorick',
#  'Alvin L. Marty',
#  'Alvin Murphy',
#  'Alvin Ulrich',
#  'Alwyn Young',
#  'Amalia R. Miller',
#  'Aman Ullah',
#  'Amanda E. Kowalski',
#  'Amanda Friedenberg',
#  'Amanda Gosling',
#  'Amanda Pallais',
#  'Amanda Starc',
#  'Amartya K. Sen',
#  'Amartya Lahiri',
#  'Amartya Sen',
#  'Ameet Morjaria',
#  'Amil Petrin',
#  'Amin H. Amershi',
#  'Amir E. Khandani',
#  'Amir Jina',
#  'Amir S. Jina',
#  'Amir Sufi',
#  'Amir Yaron',
#  'Amit Gandhi',
#  'Amit K. Khandelwal',
#  'Amit Kumar Khandelwal',
#  'Amit Seru',
#  'Amitabh Chandra',
#  'Amnon Rapoport',
#  'Amos Tversky',
#  'Amparo Urbano',
#  'Amrita Dhillon',
#  'Amy Ellen Schwartz',
#  'Amy Finkelstein',
#  'Amy K. Dittmar',
#  'Amy L. Bertin',
#  'Amy Taylor',
#  'Ana Castañeda',
#  'Ana Cecília Fieler',
#  'Ana Fostel',
#  'Ana L. Revenga',
#  'Ana M. Ferrer',
#  'Anand V. Swamy',
#  'Ananth Ramanarayanan',
#  'Ananth Seshadri',
#  'Anastasios Xepapadeas',
#  'Anat Bracha',
#  'Anat R. Admati',
#  'Anders Akerman',
#  'Anders Björklund',
#  'Anders Klevmarken',
#  'Anders Poulsen',
#  'Anders Rahbek',
#  'Anders Rygh Swensen',
#  'Andrea Attar',
#  'Andrea Frazzini',
#  'Andrea Generale',
#  'Andrea Ichino',
#  'Andrea L. Eisfeldt',
#  'Andrea Moro',
#  'Andrea Prat',
#  'Andrea Shepard',
#  'Andrea Szabó',
#  'Andrea Tambalotti',
#  'Andrea Vindigni',
#  'Andrea Weber',
#  'Andrea Wilson',
#  'Andreas Blume',
#  'Andreas Fuster',
#  'Andreas Herrmann',
#  'Andreas I. Mueller',
#  'Andreas Kontoleon',
#  'Andreas Lange',
#  'Andreas Madestam',
#  'Andreas Moxnes',
#  'Andreas Park',
#  'Andreas Ravndal Kostøl',
#  'Andreas Roider',
#  'Andrei A. Levchenko',
#  'Andrei Kirilenko',
#  'Andrei Shleifer',
#  'Andres Babino',
#  'Andres Erosa',
#  'Andres Rodriguez‐Clare',
#  'Andres Santos',
#  'Andres Velasco',
#  'Andreu Mas-Colell',
#  'Andrew A. Samwick',
#  'Andrew Atkeson',
#  'Andrew B. Abel',
#  'Andrew B. Bernard',
#  'Andrew Caplin',
#  'Andrew Charlton',
#  'Andrew Chesher',
#  'Andrew Ching',
#  'Andrew D. Foster',
#  'Andrew F. Daughety',
#  'Andrew F. Newman',
#  'Andrew Foster',
#  'Andrew G. Atkeson',
#  'Andrew Goodman-Bacon',
#  'Andrew Haughwout',
#  'Andrew J. Oswald',
#  'Andrew J. Plantinga',
#  'Andrew J. Policano',
#  'Andrew J. Seltzer',
#  'Andrew John',
#  'Andrew Johnston',
#  'Andrew K. Rose',
#  'Andrew M. Warner',
#  'Andrew McLennan',
#  'Andrew Metrick',
#  'Andrew Morton',
#  'Andrew Postlewaite',
#  'Andrew Rose',
#  'Andrew S. Caplin',
#  'Andrew Schmitz',
#  'Andrew Schotter',
#  'Andrew Sweeting',
#  'Andrew T. Foerster',
#  'Andrew V. Carter',
#  'Andrew W. Lo',
#  'Andrew Weiss',
#  'Andrew Whinston',
#  'Andrey Fradkin',
#  'Andrey Malenko',
#  'Andriy Norets',
#  'Andrzej Rapaczynski',
#  'Andrzej Ruszczyński',
#  'Andrzej Skrzypacz',
#  'András Nagy',
#  'André Sapir',
#  'André de Palma',
#  'Andrés Aradillas-López',
#  'Andrés Carvajal',
#  'Andrés Rodríguez-Clare',
#  'Andrés Velasco',
#  'Aner Sela',
#  'Angel Serrat',
#  'Angela K. Dills',
#  'Angus Deaton',
#  'Angus S. Deaton',
#  'Anil B. Deolalikar',
#  'Anil K Kashyap',
#  'Anil K. Kashyap',
#  'Anil Kashyap',
#  'Aniol Llorente-Saguer',
#  'Anirban Mitra',
#  'Anjan Mukherji',
#  'Anjan V. Thakor',
#  'Anjini Kochar',
#  'Anke S. Kessler',
#  'Ann A. McDermed',
#  'Ann Bartel',
#  'Ann D. Witte',
#  'Ann Dryden Witte',
#  'Ann E. Harrison',
#  'Ann P. Bartel',
#  'Anna Aizer',
#  'Anna Bogomolnaia',
#  'Anna Dreber',
#  'Anna J. Schwartz',
#  'Anna L. Paulson',
#  'Anna Maria Mayda',
#  'Anna Mikusheva',
#  'Anna Pavlova',
#  'Anna Salomons',
#  'Annamaria Lusardi',
#  'Anne Brockmeyer',
#  'Anne C. Case',
#  'Anne Case',
#  'Anne O. Krueger',
#  'Anne P. Villamil',
#  'Annette Vissing-Jorgensen',
#  'Annette Vissing-Jørgensen',
#  'Annette Vissing‐Jørgensen',
#  'Annika Sundén',
#  'Anthony A. Smith, Jr.',
#  'Anthony C. Fisher',
#  'Anthony F. Shorrocks',
#  'Anthony G. Lawrence',
#  'Anthony J. Venables',
#  'Anthony Leung',
#  'Anthony M. Kwasnica',
#  "Anthony Patrick O'Brien",
#  'Anthony Paul',
#  'Anthony Romeo',
#  'Anthony Y. C. Koo',
#  'Antoine Billot',
#  'Antoine Bozio',
#  'Antoinette Schoar',
#  'Anton P. Barten',
#  'Antonella Trigari',
#  'Antoni Calvó-Armengol',
#  'Antoni Calvó‐Armengol',
#  'Antoni Estevadeordal',
#  'Antoni Zabalza',
#  'Antonin Macé',
#  'Antonio Cabrales',
#  'Antonio Ciccone',
#  'Antonio Doblas-Madrid',
#  'Antonio E. Bernardo',
#  'Antonio Fatás',
#  'Antonio Guarino',
#  'Antonio J. Morales',
#  'Antonio Merlo',
#  'Antonio Penta',
#  'Antonio Rangel',
#  'Antoon van den Elzen',
#  'Anup Malani',
#  'Aprajit Mahajan',
#  'April M. Franco',
#  'Ar-Young Wang',
#  'Argia M. Sbordone',
#  'Ari Kuncoro',
#  'Arie Beresteanu',
#  'Arie Kapteyn',
#  'Arie Melnik',
#  'Ariel Burstein',
#  'Ariel Pakes',
#  'Ariel Rubinstein',
#  'Ariel T. Burstein',
#  'Ariel Tomás Burstein',
#  'Ariel Zetlin-Jones',
#  'Ariell Reshef',
#  'Arijit Mukherji',
#  'Arijit Sen',
#  'Arindrajit Dube',
#  'Aris Protopapadakis',
#  'Arja H. Turunen-Red',
#  'Arleen Leibowitz',
#  'Arline T. Geronimus',
#  'Arlington W. Williams',
#  'Armando Gomes',
#  'Armen Alchian',
#  'Armin Falk',
#  'Arnaud Costinot',
#  'Arnaud Dupuy',
#  'Arno Riedl',
#  'Arnold C. Harberger',
#  'Arnold Zellner',
#  'Arnoud W. A. Boot',
#  'Arpit Gupta',
#  'Arthur A. Small',
#  'Arthur A. Stone',
#  'Arthur A. van Benthem',
#  'Arthur De Vany',
#  'Arthur E. Gandolfi',
#  'Arthur Fishman',
#  'Arthur Havenner',
#  'Arthur J. Gartaganis',
#  'Arthur J. Hosios',
#  'Arthur J. Robson',
#  'Arthur J. Rolnick',
#  'Arthur Lewbel',
#  'Arthur P. Hurter, Jr.',
#  'Arthur Robson',
#  'Arthur S. De Vany',
#  'Arthur S. Goldberger',
#  'Arthur Smithies',
#  'Arthur Snow',
#  'Arthur Van Soest',
#  'Arthur van Soest',
#  'Artur Raviv',
#  'Artyom Shneyerov',
#  'Arunava Sen',
#  'Arvind Krishnamurthy',
#  'Arvind Panagariya',
#  'Arye L. Hillman',
#  'Asaf Zussman',
#  'Asen Ivanov',
#  'Asen Kochov',
#  'Asger Lunde',
#  'Asher Wolinsky',
#  'Ashiq Hussain',
#  'Ashok Kotwal',
#  'Ashoka Mody',
#  'Asim Ijaz Khwaja',
#  'Assaf Razin',
#  'Assar Lindbeck',
#  'Astri Drange Hole',
#  'Asuman Ozdaglar',
#  'Athanasios Orphanides',
#  'Atif Mian',
#  'Atila Abdulkadiroğlu',
#  'Atila Abdulkadiroǧlu',
#  'Atish R. Ghosh',
#  'Atonu Rabbani',
#  'Atsushi Kajii',
#  'Atsushi Ohyama',
#  'Attila Ambrus',
#  'Aubhik Khan',
#  'Audrey Guo',
#  'Augustin Landier',
#  'Aurélien Baillon',
#  'Austan Goolsbee',
#  'Avery M. Guest',
#  'Avi Goldfarb',
#  'Avi Simhon',
#  'Avi Wigderson',
#  'Avia Spivak',
#  'Aviad Heifetz',
#  'Avinash Dixit',
#  'Avinash K. Dixit',
#  'Avinatan Hassidim',
#  'Aviv Nevo',
#  'Avner Bar-Ilan',
#  'Avner Ben-Ner',
#  'Avner Greif',
#  'Avner Shaked',
#  'Avner Shared',
#  'Axel Mossin',
#  'Axel Ockenfels',
#  'Ayman Hindy',
#  'Ayşe Imrohoroğlu',
#  'Ayşe İmrohoroğlu',
#  'Azam Chaudhry',
#  'Azeem M. Shaikh',
#  'B. Caillaud',
#  'B. Curtis Eaton',
#  'B. Curtis Eaves',
#  'B. Douglas Bernheim',
#  'B. Jullien',
#  'B. Mellon',
#  'B. P. Banerjee',
#  'B. Peleg',
#  'B. Peter Pashigian',
#  'B. Peter Rosendorff',
#  'B. Piedad Urdinola',
#  'B. Ravikumar',
#  'B. Singer',
#  'B. T. McCallum',
#  'Babu Nahata',
#  'Badi H. Baltagi',
#  'Balazs Szentes',
#  'Balvir Singh',
#  'Balázs Szentes',
#  'Barbara J. Mace',
#  'Barbara L. Wolfe',
#  'Barbara McCutcheon',
#  'Barbara Petrongolo',
#  'Barbara R. Bergmann',
#  'Barbara Rossi',
#  'Barrett E. Kirwan',
#  'Barry C. Field',
#  'Barry Falk',
#  'Barry Nalebuff',
#  'Barry Naughton',
#  'Barry R. Chiswick',
#  'Barry R. Weingast',
#  'Barry Sopher',
#  'Barry W. Ickes',
#  'Bart Hobijn',
#  'Bart J. Bronnenberg',
#  'Bart J. Wilson',
#  'Bart Taub',
#  'Bartholomew J. Moore',
#  'Barton H. Hamilton',
#  'Barton L. Lipman',
#  'Basant K. Kapur',
#  'Bastiaan Oud',
#  'Bauke Visser',
#  'Behzad T. Diba',
#  'Bela Balassa',
#  'Ben Bernanke',
#  'Ben Branch',
#  'Ben Craig',
#  'Ben Greiner',
#  'Ben Groom',
#  'Ben Handel',
#  'Ben Lockwood',
#  'Ben Polak',
#  'Ben S. Bernanke',
#  'Benedikt Herrmann',
#  'Benedikt M. Pötscher',
#  'Bengt Holmstrom',
#  'Bengt Holmström',
#  'Benjamin A. Malin',
#  'Benjamin A. Olken',
#  'Benjamin Bental',
#  'Benjamin Brooks',
#  'Benjamin Cheng',
#  'Benjamin Conlee',
#  'Benjamin E. Hermalin',
#  'Benjamin Edelman',
#  'Benjamin Eden',
#  'Benjamin F. Jones',
#  'Benjamin Golub',
#  'Benjamin Handel',
#  'Benjamin I. Cohen',
#  'Benjamin J. Keys',
#  'Benjamin Klein',
#  'Benjamin M. Friedman',
#  'Benjamin M. Sand',
#  'Benjamin Moll',
#  'Benjamin N. Roin',
#  'Benjamin Sand',
#  'Benjamin Van Roy',
#  'Benn Eifert',
#  'Bennett Harrison',
#  'Bennett T. McCallum',
#  'Benny D. Bowers',
#  'Benny Moldovanu',
#  'Bent E. Sørensen',
#  'Benton F. Massell',
#  'Benyamin Shitovitz',
#  'Berk Özler',
#  'Bernard Caillaud',
#  'Bernard Cornet',
#  'Bernard Fortin',
#  'Bernard Salanie',
#  'Bernard Salanié',
#  'Bernard van Praag',
#  'Bernd Irlenbusch',
#  'Bernhard von Stengel',
#  'Bernt P. Stigum',
#  'Bert M. Balk',
#  'Bertil Tungodden',
#  'Bertrand Rime',
#  'Beth Allen',
#  'Betsey Stevenson',
#  'Bev Dahlby',
#  'Bezalel Peleg',
#  'Bhagwan Chowdhry',
#  'Bhashkar Mazumder',
#  'Bhaskar Dutta',
#  'Bhu Dev Sharma',
#  'Bianca L. De Stavola',
#  'Bijan B. Aghevli',
#  'Bilge Yilmaz',
#  'Bilge Yılmaz',
#  'Bill Dupor',
#  'Bill M. Woodland',
#  'Bill Wright',
#  'Bin Chen',
#  'Binzhen Wu',
#  'Birger Wernerfelt',
#  'Birgit Grodal',
#  'Birgit Heydenreich',
#  'Björn Bartling',
#  'Björn Tyrefors Hinnerich',
#  'Björn Wallace',
#  'Björn Öckert',
#  'Blaine Roberts',
#  'Blaise Melly',
#  'Bo Axell',
#  'Bo Cowgill',
#  'Bo E. Honoré',
#  'Botond Köszegi',
#  'Botond Kőszegi',
#  'Boyan Jovanovic',
#  'Brad M. Barber',
#  'Bradford Cornell',
#  'Bram De Rock',
#  'Bram Thuysbaert',
#  'Bram de Rock',
#  'Brandice Canes-Wrone',
#  'Branko Urošević',
#  'Brendan Daley',
#  'Brendan K. Beare',
#  'Brendan Lucier',
#  'Brendan O’Flaherty',
#  'Brendan Price',
#  'Brendon McConnell',
#  'Breno Braga',
#  'Brent Neiman',
#  'Brent Sohngen',
#  'Brett Gordon',
#  'Brett Green',
#  'Brett J. Noel',
#  'Brett R. Gordon',
#  'Brian A. Jacob',
#  'Brian Blackburn',
#  'Brian Bowen',
#  'Brian D. Wright',
#  'Brian Frantz',
#  'Brian Hill',
#  'Brian Hillier',
#  'Brian J. Hall',
#  'Brian K. Kovak',
#  'Brian Knight',
#  'Brian L. Bentick',
#  'Brian Merlob',
#  'Brian P. McCall',
#  'Brian R. Copeland',
#  'Brian Sack',
#  'Brian T. Melzer',
#  'Brian W. Rogers',
#  'Brian Wallace',
#  'Bridger M. Mitchell',
#  'Bridget Terry Long',
#  'Brigitte C. Madrian',
#  'Bronwyn H. Hall',
#  'Brook S. Payner',
#  'Brooks Pierce',
#  'Bruce A. Blonigen',
#  'Bruce A. Weinberg',
#  'Bruce Bender',
#  'Bruce C. Dieffenbach',
#  'Bruce C. Greenwald',
#  'Bruce C. Petersen',
#  'Bruce Champ',
#  'Bruce D. Meyer',
#  'Bruce D. Smith',
#  'Bruce E. Hansen',
#  'Bruce I. Sacerdote',
#  'Bruce L. Gardner',
#  'Bruce L. Miller',
#  'Bruce M. Wetzel',
#  'Bruce N. Lehmann',
#  'Bruce Preston',
#  'Bruce Rhodes',
#  'Bruce Robert Kingma',
#  'Bruce Sacerdote',
#  'Bruce Smith',
#  'Bruce W. Hamilton',
#  'Bruce Wydick',
#  'Bruno Biais',
#  'Bruno Broseta',
#  'Bruno Contini',
#  'Bruno Crépon',
#  'Bruno Ferman',
#  'Bruno Jullien',
#  'Bruno L. S. Falcão',
#  'Bruno S. Frey',
#  'Bruno Strulovici',
#  'Bryan E. Stanhouse',
#  'Bryan Ellickson',
#  'Bryan L. Boulier',
#  'Bryan S. Graham',
#  'Bryan W. Brown',
#  'Burcu Eyigungor',
#  'Burhanettin Kuruşçu',
#  'Burton A. Abrams',
#  'Burton A. Weisbrod',
#  'Burton G. Malkiel',
#  'Burton Zwick',
#  'Byong-Hyong Bahk',
#  'Byoung Jun',
#  'Byran W. Brown',
#  'Byron F. Lutz',
#  'Byron G. Spencer',
#  'Byron W. Brown',
#  'Byung Sam Yoo',
#  'Byung-Joo Lee',
#  'Byung-Kun Rhee',
#  'Byung-Nak Song',
#  'Bård Harstad',
#  'Béla Martos',
#  'C. A. Blyth',
#  'C. B. Tilanus',
#  'C. Blackorby',
#  'C. Christian von Weizsäcker',
#  'C. D. Aliprantis',
#  'C. Duncan MacRae',
#  'C. E. Ferguson',
#  'C. E. Phelps',
#  'C. E. V. Leser',
#  'C. Fourgeaud',
#  'C. Fritz Foley',
#  'C. Gourieroux',
#  'C. H. Hanumantha Rao',
#  'C. Hansen',
#  'C. J. van Eijk',
#  'C. L. F. Attfield',
#  'C. Lanier Benkard',
#  'C. M. K. Watts',
#  'C. M. Lindsay',
#  'C. Meghir',
#  'C. Oddou',
#  'C. P. Hallwood',
#  'C. P. Timmer',
#  'C. R. S. Dougherty',
#  'C. R. Wymer',
#  'C. T. Leenders',
#  'C. Timothy Koeller',
#  'C. W. J. Granger',
#  'C. Y. Cyrus Chu',
#  'C. Zachary Gilstein',
#  "C. d'Aspremont",
#  'C. van de Panne',
#  'Caglar Ozden',
#  'Camille Landais',
#  'Camilo Dagum',
#  'Camilo García-Jimeno',
#  'Campbell R. Harvey',
#  'Canice Prendergast',
#  'Cara S. Lown',
#  'Caralee McLiesh',
#  'Carl A. Futia',
#  'Carl Davidson',
#  'Carl E. Walsh',
#  'Carl F. Christ',
#  'Carl M. CampbellIII',
#  'Carl P. Simon',
#  'Carl Shapiro',
#  'Carl Wennerlind',
#  'Carlos A. Flores',
#  'Carlos A. Végh',
#  'Carlos Alfredo Rodriguez',
#  'Carlos Alfredo Rodríguez',
#  'Carlos Dobkin',
#  'Carlos E. da Costa',
#  'Carlos J. Ponce',
#  'Carlos Rodríguez-Palmero',
#  'Carlos Urrutia',
#  'Carlos Vargas-Silva',
#  'Carlos Velasco',
#  'Carlton Hubbard',
#  'Carmen F. Menezes',
#  'Carmen M. Reinhart',
#  'Carmen Tanner',
#  'Carol Ann Rogers',
#  'Carol J. Simon',
#  'Carol Propper',
#  'Carola Frydman',
#  'Carolina Caetano',
#  'Carolina Villegas-Sanchez',
#  'Caroline Freund',
#  'Caroline Hoxby',
#  'Caroline M. Hoxby',
#  'Caroline Minter Hoxby',
#  'Caroline Ratcliffe',
#  'Carolyn B. Levine',
#  'Carolyn L. Weaver',
#  'Carolyn Pitchik',
#  'Cars H. Hommes',
#  'Carsten Trenkler',
#  'Cary Deck',
#  'Casey B. Mulligan',
#  'Casey Ichniowski',
#  'Casey Rothschild',
#  'Catherine D. Wolfram',
#  'Catherine E. Tucker',
#  'Catherine Eckel',
#  'Catherine J. Morrison',
#  'Catherine Thomas',
#  'Catherine Tucker',
#  'Catherine Wolfram',
#  'Cecilia Elena Rouse',
#  'Cecilia Rouse',
#  'Celeste Saravia',
#  'Cezar Santos',
#  'Chad Syverson',
#  'Chaehee Shin',
#  'Chaim Fershtman',
#  'Chandra Kanodia',
#  'Chang-Tai Hsieh',
#  'Changyong Rhee',
#  'Chang‐Tai Hsieh',
#  'Chantale LaCasse',
#  'Chao Fu',
#  'Chao Gu',
#  'Charles A. Holt',
#  'Charles A. Holt, Jr.',
#  'Charles A. M. de Bartolome',
#  'Charles A. Wilson',
#  'Charles Bellemare',
#  'Charles Blackorby',
#  'Charles Brown',
#  'Charles C. Cox',
#  'Charles C. Holt',
#  'Charles C. Ying',
#  'Charles D. Kolstad',
#  'Charles E. McCulloch',
#  'Charles E. McLure, Jr.',
#  'Charles E. Phelps',
#  'Charles E. Stuart',
#  'Charles Engel',
#  'Charles F. Manski',
#  'Charles G. Geiss',
#  'Charles H. Kriebel',
#  'Charles H. Whiteman',
#  'Charles I. Jones',
#  'Charles I. Plosser',
#  'Charles J. Cicchetti',
#  'Charles J. Jacklin',
#  'Charles J. Redlick',
#  'Charles K. Rowley',
#  'Charles Kahn',
#  'Charles L. Ballard',
#  'Charles L. Evans',
#  'Charles M. Beach',
#  'Charles M. Kahn',
#  'Charles Michalopoulos',
#  'Charles Morcom',
#  'Charles N. Noussair',
#  'Charles Nolan',
#  'Charles P. Thomas',
#  'Charles Plott',
#  'Charles R. Hulten',
#  'Charles R. Link',
#  'Charles R. Nelson',
#  'Charles R. Pierret',
#  'Charles R. Plott',
#  'Charles S. Roehrig',
#  'Charles Sprenger',
#  'Charles Stuart',
#  'Charles T. Carlstrom',
#  'Charles T. Clotfelter',
#  'Charles Towe',
#  'Charles W. Calomiris',
#  'Charles W. Upton',
#  'Charles Wilson',
#  'Charles Z. Zheng',
#  'Charles Zhoucheng Zheng',
#  'Charlotte Ostergaard',
#  'Chau-nan Chen',
#  'Che-Lin Su',
#  'Chemi Gotlibovski',
#  'Cheng Hsiao',
#  'Cheng Wang',
#  'Chenggang Xu',
#  'Cheryl Gray',
#  'Chester S. Spatt',
#  'Chester Spatt',
#  'Chew Soo Hong',
#  'Chi-Fu Huang',
#  'Chi-Keung Woo',
#  'Chi-fu Huang',
#  'Chia-Shang James Chu',
#  'Chiaki Hara',
#  'Chihwa Kao',
#  'Chin Hock Ow',
#  'Ching-I Huang',
#  'Ching-To Albert Ma',
#  'Ching-to Albert Ma',
#  'Chinhui Juhn',
#  'Chip Heath',
#  'Chirok Han',
#  'Chong Xiang',
#  'Choon-Geol Moon',
#  'Chris Bidner',
#  'Chris Edmond',
#  'Chris I. Telmer',
#  'Chris J. McKenna',
#  'Chris Nosko',
#  'Chris Orme',
#  'Chris Robinson',
#  'Chris Shannon',
#  ...]

# %% [markdown]
# ## Create Gender Information
#
# This section tries to match each authors appearring in the combined dataset to his/her gender, according to Hangel's list of gender.
#
# I constructed an transformation rule that deals with issues like abbreviations, neglection on middle-name, and so on, to match as many as possible the gender.

# %%
with open('sex_json.json','r') as j:    
    erin_author_sex = json.loads(j.read())

# %%
# abbreviations
new_sex = dict()
for name, sex in erin_author_sex.items():
    name_sections = re.split(' (?!Jr.)', name)
    last_name = name_sections[-1]
    name_section_num = len(name_sections)
    
    if name_section_num == 1: continue
    other_than_lastname = name_sections[:-1]
    abbr_other = [f"{s[0]}." for s in other_than_lastname]
    choosing_list = [[other_than_lastname[i], abbr_other[i]] for i in range(name_section_num-1)]
    for combination in list(itertools.product([0, 1], repeat=name_section_num-1)):
        new_name = ' '.join(
            [choosing_list[i][combination[i]] for i in range(name_section_num-1)]+[last_name])
        new_sex.update({new_name:sex})
                      
    if name_section_num == 3:
        no_middle_name = f"{name_sections[0]} {name_sections[2]}"
        new_sex.update({no_middle_name:sex})

# %%
sexes = []
# match each name that appears to the gender list created above
for a in all_authors:
    sex = None
    if a in new_sex:
        sex = new_sex[a]
    
    sexes.append(sex)

# %%
sex_df = pd.DataFrame(zip(all_authors, sexes), columns=['Name', 'Gender'])
sex_df
# Out:
#                    Name Gender
# 0          A. A. Ryvkin      1
# 1         A. A. Walters      1
# 2      A. Abigail Payne      0
# 3     A. Anastasopoulos      1
# 4        A. Andrew John      1
# ...                 ...    ...
# 7207        Òscar Jordà      1
# 7208          Ö. Éltetö   None
# 7209       Ľuboš Pástor      1
# 7210     Şevin Yeltekin   None
# 7211         Ṣule Özler   None
#
# [7212 rows x 2 columns]

# %%
sex_df.to_csv('sex_noRes.csv')

# %%
with open("sex_json_full_temp.json",'w') as f:
    json.dump(new_sex, f)

# %% [markdown]
# ## Get the data to be ready for regression
#
# Assume that now the datas (articles that are needed is filtered, and genders are all assigned) are complete.
#
# Rerun the configuration section to load the data.

# %%
with_abs_2015
# Out:
#       Journal                           Source URL  \
# 0         AER  https://www.jstor.org/stable/116860
# 1         AER  https://www.jstor.org/stable/116861
# 2         AER  https://www.jstor.org/stable/116862
# 3         AER  https://www.jstor.org/stable/116863
# 4         AER  https://www.jstor.org/stable/116864
# ...       ...                                  ...
# 20203     QJE   https://doi.org/10.1093/qje/qjv025
# 20204     QJE   https://doi.org/10.1093/qje/qjv030
# 20205     QJE   https://doi.org/10.1093/qje/qjv023
# 20206     QJE   https://doi.org/10.1093/qje/qjv026
# 20207     QJE   https://doi.org/10.1093/qje/qjv031
#
#                                                    Title  \
# 0      The Value of Weather Information Services for ...
# 1      The Rise and Fall of Bank Control in the Unite...
# 2      Winners and Losers in Russia's Economic Transi...
# 3      Unemployment and the Social Safety Net during ...
# 4              Federalism and the Soft Budget Constraint
# ...                                                  ...
# 20203  Human Capital and Industrialization: Evidence ...
# 20204  Radio and the Rise of The Nazis in Prewar Germany
# 20205  The Unfavorable Economics of Measuring the Ret...
# 20206  Why you Can’t Find a Taxi in the Rain and Othe...
# 20207        Risk, Returns, and Multinational Production
#
#                       Long Volume  Issue Vol. Issue No.     Month    Year  \
# 0      Vol. 88, No. 5, Dec., 1998     Vol. 88     No. 5      Dec.  1998.0
# 1      Vol. 88, No. 5, Dec., 1998     Vol. 88     No. 5      Dec.  1998.0
# 2      Vol. 88, No. 5, Dec., 1998     Vol. 88     No. 5      Dec.  1998.0
# 3      Vol. 88, No. 5, Dec., 1998     Vol. 88     No. 5      Dec.  1998.0
# 4      Vol. 88, No. 5, Dec., 1998     Vol. 88     No. 5      Dec.  1998.0
# ...                           ...         ...       ...       ...     ...
# 20203                         NaN  Volume 130   Issue 4  November  2015.0
# 20204                         NaN  Volume 130   Issue 4  November  2015.0
# 20205                         NaN  Volume 130   Issue 4  November  2015.0
# 20206                         NaN  Volume 130   Issue 4  November  2015.0
# 20207                         NaN  Volume 130   Issue 4  November  2015.0
#
#                                                 Abstract  \
# 0      The U.S. government established a national wea...
# 1      This article studies how equity ownership and ...
# 2      The transition to a market economy has produce...
# 3      We investigate the remarkably short unemployme...
# 4      The government's incentives to bail out ineffi...
# ...                                                  ...
# 20203  While human capital is a strong predictor of e...
# 20204  How do the media affect public support for dem...
# 20205  Twenty-five large field experiments with major...
# 20206  I replicate and extend the seminal work of Cam...
# 20207  This article starts by unveiling a strong empi...
#
#                                           Full Author               Author 1  \
# 0                                       Erik D. Craft          Erik D. Craft
# 1                               Miguel Cantillo Simon  Miguel Cantillo Simon
# 2                                  Elizabeth Brainerd     Elizabeth Brainerd
# 3      John C. Ham, Jan Svejnar and Katherine Terrell            John C. Ham
# 4                       Yingyi Qian and Gérard Roland            Yingyi Qian
# ...                                               ...                    ...
# 20203                                             NaN   Mara P. Squicciarini
# 20204                                             NaN             Maja Adena
# 20205                                             NaN       Randall A. Lewis
# 20206                                             NaN        Henry S. Farber
# 20207                                             NaN         José L. Fillat
#
#                Author 2           Author 3            Author 4  \
# 0                   NaN                NaN                 NaN
# 1                   NaN                NaN                 NaN
# 2                   NaN                NaN                 NaN
# 3           Jan Svejnar  Katherine Terrell                 NaN
# 4         Gérard Roland                NaN                 NaN
# ...                 ...                ...                 ...
# 20203  Nico Voigtländer                NaN                 NaN
# 20204  Ruben Enikolopov      Maria Petrova  Veronica Santarosa
# 20205     Justin M. Rao                NaN                 NaN
# 20206               NaN                NaN                 NaN
# 20207  Stefania Garetto                NaN                 NaN
#
#                     Author 5 Author 6 Author 7 Author 8
# 0                        NaN      NaN      NaN      NaN
# 1                        NaN      NaN      NaN      NaN
# 2                        NaN      NaN      NaN      NaN
# 3                        NaN      NaN      NaN      NaN
# 4                        NaN      NaN      NaN      NaN
# ...                      ...      ...      ...      ...
# 20203                    NaN      NaN      NaN      NaN
# 20204  Ekaterina Zhuravskaya      NaN      NaN      NaN
# 20205                    NaN      NaN      NaN      NaN
# 20206                    NaN      NaN      NaN      NaN
# 20207                    NaN      NaN      NaN      NaN
#
# [9385 rows x 18 columns]

# %%
from textatistic import Textatistic, punct_clean

# %%
with open('sex_json_full.json','r') as j:    
    author_sex_dict = json.loads(j.read())

# %%
def mutate_author(row):
    sex_rate = []
    for i in range(8):
        current_aut_col = f"Author {i+1}"
        if row[current_aut_col] == '':
            continue
        sex_col = f"Gender {i+1}"
        
        author = row[current_aut_col]
        
        if author not in author_sex_dict:
            row['Author Error'] = 1
            return row
        sex = author_sex_dict[author]
        row[sex_col] = sex
        sex_rate.append(int(sex))
    row['Gender Score'] = np.mean(sex_rate)
    return row

# %%
## "with_abs_2015" represents the final combined result. It is for now uncomplete
## once the list of articals are constructed, change it to that.

with_abs_2015 = with_abs_2015.replace({np.nan: ''})
with_abs_2015
# Out:
#       Journal                           Source URL  \
# 0         AER  https://www.jstor.org/stable/116860
# 1         AER  https://www.jstor.org/stable/116861
# 2         AER  https://www.jstor.org/stable/116862
# 3         AER  https://www.jstor.org/stable/116863
# 4         AER  https://www.jstor.org/stable/116864
# ...       ...                                  ...
# 20203     QJE   https://doi.org/10.1093/qje/qjv025
# 20204     QJE   https://doi.org/10.1093/qje/qjv030
# 20205     QJE   https://doi.org/10.1093/qje/qjv023
# 20206     QJE   https://doi.org/10.1093/qje/qjv026
# 20207     QJE   https://doi.org/10.1093/qje/qjv031
#
#                                                    Title  \
# 0      The Value of Weather Information Services for ...
# 1      The Rise and Fall of Bank Control in the Unite...
# 2      Winners and Losers in Russia's Economic Transi...
# 3      Unemployment and the Social Safety Net during ...
# 4              Federalism and the Soft Budget Constraint
# ...                                                  ...
# 20203  Human Capital and Industrialization: Evidence ...
# 20204  Radio and the Rise of The Nazis in Prewar Germany
# 20205  The Unfavorable Economics of Measuring the Ret...
# 20206  Why you Can’t Find a Taxi in the Rain and Othe...
# 20207        Risk, Returns, and Multinational Production
#
#                       Long Volume  Issue Vol. Issue No.     Month    Year  \
# 0      Vol. 88, No. 5, Dec., 1998     Vol. 88     No. 5      Dec.  1998.0
# 1      Vol. 88, No. 5, Dec., 1998     Vol. 88     No. 5      Dec.  1998.0
# 2      Vol. 88, No. 5, Dec., 1998     Vol. 88     No. 5      Dec.  1998.0
# 3      Vol. 88, No. 5, Dec., 1998     Vol. 88     No. 5      Dec.  1998.0
# 4      Vol. 88, No. 5, Dec., 1998     Vol. 88     No. 5      Dec.  1998.0
# ...                           ...         ...       ...       ...     ...
# 20203                              Volume 130   Issue 4  November  2015.0
# 20204                              Volume 130   Issue 4  November  2015.0
# 20205                              Volume 130   Issue 4  November  2015.0
# 20206                              Volume 130   Issue 4  November  2015.0
# 20207                              Volume 130   Issue 4  November  2015.0
#
#                                                 Abstract  \
# 0      The U.S. government established a national wea...
# 1      This article studies how equity ownership and ...
# 2      The transition to a market economy has produce...
# 3      We investigate the remarkably short unemployme...
# 4      The government's incentives to bail out ineffi...
# ...                                                  ...
# 20203  While human capital is a strong predictor of e...
# 20204  How do the media affect public support for dem...
# 20205  Twenty-five large field experiments with major...
# 20206  I replicate and extend the seminal work of Cam...
# 20207  This article starts by unveiling a strong empi...
#
#                                           Full Author               Author 1  \
# 0                                       Erik D. Craft          Erik D. Craft
# 1                               Miguel Cantillo Simon  Miguel Cantillo Simon
# 2                                  Elizabeth Brainerd     Elizabeth Brainerd
# 3      John C. Ham, Jan Svejnar and Katherine Terrell            John C. Ham
# 4                       Yingyi Qian and Gérard Roland            Yingyi Qian
# ...                                               ...                    ...
# 20203                                                   Mara P. Squicciarini
# 20204                                                             Maja Adena
# 20205                                                       Randall A. Lewis
# 20206                                                        Henry S. Farber
# 20207                                                         José L. Fillat
#
#                Author 2           Author 3            Author 4  \
# 0
# 1
# 2
# 3           Jan Svejnar  Katherine Terrell
# 4         Gérard Roland
# ...                 ...                ...                 ...
# 20203  Nico Voigtländer
# 20204  Ruben Enikolopov      Maria Petrova  Veronica Santarosa
# 20205     Justin M. Rao
# 20206
# 20207  Stefania Garetto
#
#                     Author 5 Author 6 Author 7 Author 8
# 0
# 1
# 2
# 3
# 4
# ...                      ...      ...      ...      ...
# 20203
# 20204  Ekaterina Zhuravskaya
# 20205
# 20206
# 20207
#
# [9385 rows x 18 columns]

# %%
with_sex = with_abs_2015.apply(mutate_author, axis=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
with_sex.columns
# Out:
# Index(['Abstract', 'Author 1', 'Author 2', 'Author 3', 'Author 4', 'Author 5',
#        'Author 6', 'Author 7', 'Author 8', 'Author Error', 'Full Author',
#        'Issue No.', 'Issue Vol.', 'Journal', 'Long Volume', 'Month', 'Sex 1',
#        'Sex 2', 'Sex 3', 'Sex 4', 'Sex 5', 'Sex 6', 'Sex 7', 'Sex Score',
#        'Source URL', 'Title', 'Year'],
#       dtype='object')

# %%
def readability_columns(row):
    abstract = row['Abstract']
    try:
        r = Textatistic(abstract)
        row['Dale-Chall'] = r.dalechall_score
        row['Flesch Reading Ease'] = r.flesch_score
        row['Flesch-Kincaid'] = r.fleschkincaid_score
        row['Gunning Fog'] = r.gunningfog_score
        row['SMOG'] = r.smog_score
        return row
    except:
        print(row['Title'])
        row['Readability Score Err'] = 1
        return row

# %%
with_read = with_sex.apply(readability_columns, axis = 1)
# Out:
# A Dual-Self Model of Impulse Control
# Inherited Control and Firm Performance
# Cognition and Behavior in Two-Person Guessing Games: An Experimental Study
# The Speed of Learning in Noisy Games: Partial Reinforcement and the Sustainability of Cooperation
# Individual Preferences, Monetary Gambles, and Stock Market Participation: A Case for Narrow Framing
# Shocks and Government Beliefs: The Rise and Fall of American Inflation
# Stock Prices, News, and Economic Fluctuations

# %%
col_names = [
    "Journal",
    "Source URL",
    "Title",
    "Long Volume", "Issue Vol.", "Issue No.",
    "Month", "Year",
    "Abstract",
    "Full Author"] + \
    [f"Author {i+1}" for i in range(7)] + \
    [f"Sex {i+1}" for i in range(7)] +\
    ["Sex Score"] +\
    ['Dale-Chall','Flesch Reading Ease','Flesch-Kincaid','Gunning Fog', 'SMOG'] +\
    ['Readability Score Err']
with_read = with_read[col_names]

# %%
with_read.to_csv('reg_dat.csv', index=None)
